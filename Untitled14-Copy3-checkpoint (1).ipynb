# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
file_path = "C:/Users/vyshn/Downloads/channel_details-checkpoint.csv"
df = pd.read_csv(file_path)
df.head(10)
# Out:
#                  channel_id        channel_title          category  \
# 0  UChbmOgxUOdT-TttaPw8-DgA   Дембельский альбом  Film & Animation
# 1  UC9WxX09vr-01lDKa322FINw   Aina Asif Official  Film & Animation
# 2  UC9nuJbEL-AMJLLqc2-ej8xQ                Bongo  Film & Animation
# 3  UC5RLcUMn6TqvRJnhBTtzWUg            Sarotsi X  Film & Animation
# 4  UCidQtV5C7o1pzZ3Xo6V9fQA              楽しいショート  Film & Animation
# 5  UCvMb_oSnpYLzCRAKPn1VuSg  MFlow Entertainment  Film & Animation
# 6  UCMyHiW13BN33Bzpb1jmtTnw          Anime Burst  Film & Animation
# 7  UCR_dCM5rAnS2hjTF5SHMq3g              NAPTOON  Film & Animation
# 8  UCHrknf1C9Hwn8HxoJG15lBw               bright  Film & Animation
# 9  UC2uqduIrS_NCnYHUEtEyv8g               Gmoydi  Film & Animation
#
#    subscriber_count  view_count  video_count                   created_at  \
# 0            162000   234156675          657  2023-10-09T13:56:49.563976Z
# 1            404000   124226694          519  2023-10-07T05:40:45.019003Z
# 2          10200000  1269940793         1361         2014-08-25T13:02:03Z
# 3           1040000  1773940347         1307  2021-01-02T21:24:52.777556Z
# 4            545000  2518747702         1048  2021-03-22T12:55:09.571244Z
# 5            510000   210811800         1041         2014-10-31T02:23:04Z
# 6            280000   251705264          437  2024-04-27T13:49:30.270614Z
# 7           2910000  1204768695          545  2023-03-16T06:47:41.426331Z
# 8            196000   224438863          259  2021-09-17T02:29:20.628354Z
# 9            803000  1709922888          466  2023-07-23T19:10:12.783063Z
#
#                                  channel_description
# 0                                                NaN
# 1  Aalamualaikum everyone\nI am Aina Asif I Hope ...
# 2  About Bongo : \nBongo owned and managed by BON...
# 3  ⚡️Sarotsi X⚡️\nAnime AMV - Anime Edit - Short ...
# 4                                                NaN
# 5  TO BE A PART OF MFLOW FAMILY!\nJoin Membership...
# 6                                                NaN
# 7  Hello, Welcome to NAPTOON! Hope you enjoy our ...
# 8          what brings you to my channel, traveller?
# 9                                                NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1530 entries, 0 to 1529
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   channel_id           1530 non-null   object
#  1   channel_title        1530 non-null   object
#  2   category             1530 non-null   object
#  3   subscriber_count     1530 non-null   int64
#  4   view_count           1530 non-null   int64
#  5   video_count          1530 non-null   int64
#  6   created_at           1530 non-null   object
#  7   channel_description  1452 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 95.8+ KB

# %%
round(df.describe())
# Out:
#        subscriber_count    view_count  video_count
# count            1530.0  1.530000e+03       1530.0
# mean          4285225.0  2.481374e+09       6603.0
# std          16414373.0  1.156181e+10      29603.0
# min                 0.0  4.000000e+00          0.0
# 25%            110250.0  3.757922e+07        246.0
# 50%            745000.0  3.008834e+08        746.0
# 75%           3077500.0  1.509188e+09       1854.0
# max         388000000.0  2.946365e+11     491443.0

# %%
duplicates = df[df.duplicated()]

# %%
duplicates
# Out:
# Empty DataFrame
# Columns: [channel_id, channel_title, category, subscriber_count, view_count, video_count, created_at, channel_description]
# Index: []

# %%
df['created_at']=df['created_at'].apply(lambda x:x.split('T')[0])
df['created_at']=pd.to_datetime(df['created_at'])

# %% [markdown]
# # Data Validation

# %%
# Check for any missing values
missing_values = df.isnull().sum()
print("Missing values per column:\n", missing_values)

# %%
# insert categorical missing values with mode
# categorical_cols = ["channel_description"]
# for col in categorical_cols:
df["channel_description"].fillna(df["channel_description"].mode()[0], inplace=True)

# %%
# Display data types
print("Data types:\n", df.dtypes)

# %%
# Check for duplicate rows
duplicates = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")

# %% [markdown]
# # EDA

# %%
Variable/column|type
--------|-------
Songname | CN
Singer1 & Singer2| CN
NoOfSingers| ND
ReleasedYear,Month,Day | ND
Noofstreams| NC
Bpm | ND
Key | CO
Mode | CO
Levels | ND

    Note:

    NC - Numeric Continuous                  CO - Categorical Ordinal      
    ND - Numeric Discrete                    CN - Categorical Nominal

# %% [markdown]
# | Column Name           | Variable Type                  |
# | --------------------- | ------------------------------ |
# | `channel_id`          | **CN** (Categorical Nominal)   |
# | `channel_title`       | **CN** (Categorical Nominal)   |
# | `category`            | **CO** (Categorical Ordinal)\* |
# | `subscriber_count`    | **NC** (Numeric Continuous)    |
# | `view_count`          | **NC** (Numeric Continuous)    |
# | `video_count`         | **ND** (Numeric Discrete)      |
# | `created_at`          | **CD** (Categorical Date)\*\*  |
# | `channel_description` | **CN** (Categorical Nominal)   |

# %%
from plotly.offline import init_notebook_mode
import plotly.express as px

init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.32.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
file_path = "C:/Users/vyshn/Downloads/channel_details-checkpoint.csv"
df = pd.read_csv(file_path)
df.head()
# Out:
#                  channel_id       channel_title          category  \
# 0  UChbmOgxUOdT-TttaPw8-DgA  Дембельский альбом  Film & Animation
# 1  UC9WxX09vr-01lDKa322FINw  Aina Asif Official  Film & Animation
# 2  UC9nuJbEL-AMJLLqc2-ej8xQ               Bongo  Film & Animation
# 3  UC5RLcUMn6TqvRJnhBTtzWUg           Sarotsi X  Film & Animation
# 4  UCidQtV5C7o1pzZ3Xo6V9fQA             楽しいショート  Film & Animation
#
#    subscriber_count  view_count  video_count                   created_at  \
# 0            162000   234156675          657  2023-10-09T13:56:49.563976Z
# 1            404000   124226694          519  2023-10-07T05:40:45.019003Z
# 2          10200000  1269940793         1361         2014-08-25T13:02:03Z
# 3           1040000  1773940347         1307  2021-01-02T21:24:52.777556Z
# 4            545000  2518747702         1048  2021-03-22T12:55:09.571244Z
#
#                                  channel_description
# 0                                                NaN
# 1  Aalamualaikum everyone\nI am Aina Asif I Hope ...
# 2  About Bongo : \nBongo owned and managed by BON...
# 3  ⚡️Sarotsi X⚡️\nAnime AMV - Anime Edit - Short ...
# 4                                                NaN

# %%
df.columns
# Out:
# Index(['channel_id', 'channel_title', 'category', 'subscriber_count',
#        'view_count', 'video_count', 'created_at', 'channel_description'],
#       dtype='object')

# %%
# !pip install simple-colors
# %pip install simple-colors
from eda import univariate
# Out:
# Requirement already satisfied: simple-colors in c:\users\vyshn\anaconda3\lib\site-packages (0.1.5)
# Requirement already satisfied: simple-colors in c:\users\vyshn\anaconda3\lib\site-packages (0.1.5)
# Note: you may need to restart the kernel to use updated packages.
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.32.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df.dtypes
# Out:
# channel_id             object
# channel_title          object
# category               object
# subscriber_count        int64
# view_count              int64
# video_count             int64
# created_at             object
# channel_description    object
# dtype: object

# %% [markdown]
# # Frequency Distribution

# %%
df['category'].value_counts()
# Out:
# category
# Travel & Events          159
# Movies                   150
# Film & Animation         123
# Comedy                   109
# Music                     98
# Entertainment             96
# Autos & Vehicles          90
# Nonprofits & Activism     90
# Sports                    88
# Science & Technology      88
# Gaming                    87
# Howto & Style             86
# Pets & Animals            84
# Education                 70
# News & Politics           59
# People & Blogs            27
# Anime                     20
# Cartoons & Animations      6
# Name: count, dtype: int64

# %% [markdown]
# # Percentage Distribution

# %%
df['category'].value_counts(normalize=True) * 100
# Out:
# category
# Travel & Events         10.39
# Movies                   9.80
# Film & Animation         8.04
# Comedy                   7.12
# Music                    6.41
# Entertainment            6.27
# Autos & Vehicles         5.88
# Nonprofits & Activism    5.88
# Sports                   5.75
# Science & Technology     5.75
# Gaming                   5.69
# Howto & Style            5.62
# Pets & Animals           5.49
# Education                4.58
# News & Politics          3.86
# People & Blogs           1.76
# Anime                    1.31
# Cartoons & Animations    0.39
# Name: proportion, dtype: float64

# %%
top_jobs = df['category'].value_counts().head(10).reset_index()
top_jobs.columns = ['category', 'Count']


fig = px.bar(
    top_jobs,
    x='category',
    y='Count',
    title='Top 10 category ',
    text='Count'
)

fig.update_traces(textposition='outside')
fig.update_layout(
    xaxis_tickangle=45,
    height=800,
    width=800
)

fig.show()

# %%
cat = df['subscriber_count']

# %% [markdown]
# # Measures of Central Tendency

# %%
print("Mean:",cat.mean())
print("Median:", cat.median())
print("Mode:", cat.mode().values[0])

# %% [markdown]
# # Measures of Dispersion

# %%
print("Range:", cat.max() - cat.min())
print("Variance:", cat.var())
print("Standard Deviation:", cat.std())
print("Five Number Summary:\n", cat.describe()[['min', '25%', '50%', '75%', 'max']])
# Out:
# Range: 388000000
# Variance: 269431636822655.62
# Standard Deviation: 16414372.873267367
# Five Number Summary:
#  min           0.00
# 25%      110250.00
# 50%      745000.00
# 75%     3077500.00
# max   388000000.00
# Name: subscriber_count, dtype: float64

# %%
Measures of Symmetry

# %%
print("Skewness:", cat.skew())
print("Kurtosis:", cat.kurt())
# Out:
# Skewness: 14.27853542897009
# Kurtosis: 274.35170331313884

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['subscriber_count'], kde=True, bins=10, color='green', edgecolor='black')
plt.title("Distribution of Subscriber Count")
plt.xlabel("Subscriber Count")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
vc= df['video_count']

# %% [markdown]
# # Measures of Central Tendency

# %%
print("Mean:",vc.mean())
print("Median:", vc.median())
print("Mode:", vc.mode().values[0])
# Out:
# Mean: 6603.348366013072
# Median: 746.5
# Mode: 1

# %% [markdown]
# # Measures of Dispersion

# %%
print("Range:", vc.max() - cat.min())
print("Variance:", vc.var())
print("Standard Deviation:", vc.std())
print("Five Number Summary:\n", vc.describe()[['min', '25%', '50%', '75%', 'max']])

# %% [markdown]
# # Measures of Symmetry

# %%
print("Skewness:", cat.skew())
print("Kurtosis:", cat.kurt())
# Out:
# Skewness: 14.27853542897009
# Kurtosis: 274.35170331313884

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['video_count'], kde=True, bins=10, color='green', edgecolor='black')
plt.title("Distribution of video_count")
plt.xlabel("video_count")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %% [markdown]
# # Frequency Distribution

# %%
df['view_count'].value_counts()
# Out:
# view_count
# 2878946597    3
# 2345503564    2
# 3578328058    2
# 2112          2
# 8365831155    2
#              ..
# 1574001501    1
# 1827288234    1
# 243453024     1
# 238178276     1
# 9500          1
# Name: count, Length: 1521, dtype: int64

# %%
Percentage Distribution

# %%
df['view_count'].value_counts(normalize=True) * 100
# Out:
# view_count
# 2878946597   0.20
# 2345503564   0.13
# 3578328058   0.13
# 2112         0.13
# 8365831155   0.13
#              ...
# 1574001501   0.07
# 1827288234   0.07
# 243453024    0.07
# 238178276    0.07
# 9500         0.07
# Name: proportion, Length: 1521, dtype: float64

# %%
view_count = df['view_count'].value_counts().head(10).reset_index()
view_count.columns = ['view_count', 'Count']

fig = px.pie(
    view_count,
    names='view_count',
    values='Count',
    title='Top 10 view_count Distribution',
)

fig.update_traces(textinfo='percent+label')
fig.show()

# %% [markdown]
# - Descriptive Stats Measures used to study data between two or more columns
#
# **Bi/Multi-Variate Combo**|**Stats Measures**
# ----|-----------
# **Numeric-Numeric...**|**Correlation (-1 to +1)**
# **Numeric-Categorical...**|**Aggregation Functions (count, min, max, avg, sum)**
# **Categorical-Categorical...**|**FDT**
#
#
#        - Correlation Coeffiecient Relation Categories
#
#                     0.75 to 1 - Strong Correlation
#                     0.50 to 0.75 - Moderate Correlation
#                     <0.50 - Weak Correlation

# %%
df
# Out:
#                     channel_id             channel_title  \
# 0     UChbmOgxUOdT-TttaPw8-DgA        Дембельский альбом
# 1     UC9WxX09vr-01lDKa322FINw        Aina Asif Official
# 2     UC9nuJbEL-AMJLLqc2-ej8xQ                     Bongo
# 3     UC5RLcUMn6TqvRJnhBTtzWUg                 Sarotsi X
# 4     UCidQtV5C7o1pzZ3Xo6V9fQA                   楽しいショート
# ...                        ...                       ...
# 1525  UClDT7lvsxowovdb2wc_snSw                Adam Tyler
# 1526  UC5hDOX1r0f3pqywlnK9YsEg               Violest Std
# 1527  UCbmcndOs-RE1F1a8b6OzhHA             Michael Smith
# 1528  UCjsVTmua72MxdcO6NYHxCIg  Ireland's Coast to Coast
# 1529  UC7pn90PpyDvEvqQW327qNvQ          Katie Palavecino
#
#                    category  subscriber_count  view_count  video_count  \
# 0          Film & Animation            162000   234156675          657
# 1          Film & Animation            404000   124226694          519
# 2          Film & Animation          10200000  1269940793         1361
# 3          Film & Animation           1040000  1773940347         1307
# 4          Film & Animation            545000  2518747702         1048
# ...                     ...               ...         ...          ...
# 1525  Cartoons & Animations                 0        1620           20
# 1526  Cartoons & Animations                 3         936            3
# 1527  Cartoons & Animations                 1         622            6
# 1528  Cartoons & Animations                18        3227           31
# 1529  Cartoons & Animations                27        9500          109
#
#                        created_at  \
# 0     2023-10-09T13:56:49.563976Z
# 1     2023-10-07T05:40:45.019003Z
# 2            2014-08-25T13:02:03Z
# 3     2021-01-02T21:24:52.777556Z
# 4     2021-03-22T12:55:09.571244Z
# ...                           ...
# 1525  2020-10-22T09:53:19.474379Z
# 1526         2015-12-12T04:49:33Z
# 1527         2016-04-01T10:02:24Z
# 1528         2016-05-08T12:50:22Z
# 1529         2006-09-30T23:24:41Z
#
#                                     channel_description
# 0                                                   NaN
# 1     Aalamualaikum everyone\nI am Aina Asif I Hope ...
# 2     About Bongo : \nBongo owned and managed by BON...
# 3     ⚡️Sarotsi X⚡️\nAnime AMV - Anime Edit - Short ...
# 4                                                   NaN
# ...                                                 ...
# 1525                                                NaN
# 1526                                                NaN
# 1527                                                NaN
# 1528  Ireland's Iconic Race across Ireland!  From En...
# 1529                                                NaN
#
# [1530 rows x 8 columns]

# %% [markdown]
#  Pure Numeric| Mixed Columns| Pure Categorical
# -----|-----|-----
#  subscriber_count vs view_count  | subscriber_count vs category | category vs channel_title
#  subscriber_count vs video_count | view_count vs category | category vs created_at
#  view_count vs video_count       | video_count vs category | created_at vs channel_title
# etc.. |etc..|ect...

# %% [markdown]
# # Bi-Variate

# %% [markdown]
# **  Pure Numeric

# %% [markdown]
# Descriptive Stats
#
# - Correlation cofficient

# %%
print("subscriber_count vs view_count")

display(round(df[['subscriber_count','view_count']].corr(),2))
# Out:
# subscriber_count vs view_count
#                   subscriber_count  view_count
# subscriber_count              1.00        0.84
# view_count                    0.84        1.00

# %%
print(" subscriber_count vs video_count ")

display(round(df[['subscriber_count','video_count']].corr(),2))
# Out:
#  subscriber_count vs video_count
#                   subscriber_count  video_count
# subscriber_count              1.00         0.12
# video_count                   0.12         1.00

# %%
print("view_count vs video_count")

display(round(df[['view_count','video_count']].corr(),2))
# Out:
# view_count vs video_count
#              view_count  video_count
# view_count         1.00         0.16
# video_count        0.16         1.00

# %%
. Visual

. Pie/Bar Char

# %%
top_10 = df.sort_values(by='subscriber_count', ascending=False).head(10)

# Create bar chart
fig = px.bar(top_10, x='channel_title', y='subscriber_count', 
             title='Top 10 channel Titles by subscribercount')
fig.show()

# %%
import plotly.express as px

fig = px.pie(df,
             names='category',
             values='subscriber_count',
             title='Subscriber Distribution by Channel Category',
             hole=0.4)  # optional: donut style
fig.show()

# %%
fig = px.pie(df,
             names='category',
             values='view_count',
             title='View Count Distribution by Category')
fig.show()

# %% [markdown]
# . Visual
#
# . Scatter/Heatmaps/Pairplots

# %%
plt.figure(figsize=(4, 3))
sns.heatmap(round(df[['subscriber_count', 'view_count']].corr(), 2), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap: "subscriber_count vs view_count"')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(4, 3))
px.scatter(df, x='video_count', y='view_count', width=600, height=350).show()

# sns.heatmap(round(data[['TotalNumberofSingers','Numb

# %% [markdown]
# . Visual
#
# . Pie/Bar Chart

# %% [markdown]
# # Multi-Variate Analysis

# %%
df.head()
# Out:
#                  channel_id       channel_title          category  \
# 0  UChbmOgxUOdT-TttaPw8-DgA  Дембельский альбом  Film & Animation
# 1  UC9WxX09vr-01lDKa322FINw  Aina Asif Official  Film & Animation
# 2  UC9nuJbEL-AMJLLqc2-ej8xQ               Bongo  Film & Animation
# 3  UC5RLcUMn6TqvRJnhBTtzWUg           Sarotsi X  Film & Animation
# 4  UCidQtV5C7o1pzZ3Xo6V9fQA             楽しいショート  Film & Animation
#
#    subscriber_count  view_count  video_count                   created_at  \
# 0            162000   234156675          657  2023-10-09T13:56:49.563976Z
# 1            404000   124226694          519  2023-10-07T05:40:45.019003Z
# 2          10200000  1269940793         1361         2014-08-25T13:02:03Z
# 3           1040000  1773940347         1307  2021-01-02T21:24:52.777556Z
# 4            545000  2518747702         1048  2021-03-22T12:55:09.571244Z
#
#                                  channel_description
# 0                                                NaN
# 1  Aalamualaikum everyone\nI am Aina Asif I Hope ...
# 2  About Bongo : \nBongo owned and managed by BON...
# 3  ⚡️Sarotsi X⚡️\nAnime AMV - Anime Edit - Short ...
# 4                                                NaN

# %%
df.corr(numeric_only=True)
# Out:
#                   subscriber_count  view_count  video_count
# subscriber_count              1.00        0.84         0.12
# view_count                    0.84        1.00         0.16
# video_count                   0.12        0.16         1.00

# %%
lower = np.triu(df.corr(numeric_only=True))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='viridis', mask=lower)
# Out:
# <Axes: >

# %%
round(df.groupby(['category', 'channel_title'])[['subscriber_count']].sum(), 2)
# Out:
#                                    subscriber_count
# category        channel_title
# Anime           Duy Khanh Le                    702
#                 Soulemani Sakare                 23
#                 bobby                            23
#                 สไบ สบาย                          2
#                 九伴动漫                            932
# ...                                             ...
# Travel & Events 片っ端から喫茶店                     105000
#                 點 Cook Guide                1220000
#                 꼬마월드                          29200
#                 남해동광호선장 박형일                  551000
#                 푸드킹덤 Food Kingdom           5140000
#
# [1381 rows x 1 columns]

# %%
round(df.groupby(['category', 'channel_title'])[['view_count']].sum(), 2)
# Out:
#                                    view_count
# category        channel_title
# Anime           Duy Khanh Le           489802
#                 Soulemani Sakare        13172
#                 bobby                    7328
#                 สไบ สบาย                 1339
#                 九伴动漫                  1209760
# ...                                       ...
# Travel & Events 片っ端から喫茶店             28882286
#                 點 Cook Guide        244123025
#                 꼬마월드                 12110219
#                 남해동광호선장 박형일        1423111338
#                 푸드킹덤 Food Kingdom  2724004837
#
# [1381 rows x 1 columns]

# %%
round(df.groupby(['category', 'channel_title'])[['video_count']].sum(), 2)
# Out:
#                                    video_count
# category        channel_title
# Anime           Duy Khanh Le               151
#                 Soulemani Sakare            16
#                 bobby                      168
#                 สไบ สบาย                     4
#                 九伴动漫                        75
# ...                                        ...
# Travel & Events 片っ端から喫茶店                   786
#                 點 Cook Guide              1602
#                 꼬마월드                       521
#                 남해동광호선장 박형일               5578
#                 푸드킹덤 Food Kingdom         1681
#
# [1381 rows x 1 columns]

# %% [markdown]
# Visual
#
# Bar/Sunburst

# %%
import plotly.express as px

fig = px.bar(df,
             x="subscriber_count",
             y="category",
             color="video_count",
             hover_data=["view_count", "channel_title"],
             height=400,
             title="Channel Performance by Category")
fig.show()

# %%
import plotly.express as px

# Sort and take top 10
top10 = df.sort_values(by='subscriber_count', ascending=False).head(10)

# Create bar chart
fig = px.bar(top10,
             x="subscriber_count",
             y="channel_title",
             color="video_count",
             hover_data=["view_count", "category"],
             height=400,
             title="Top 10 Channels by Subscriber Count")
fig.show()

# %%
import plotly.express as px

# Drop missing values in required columns
sunburst_data = df.dropna(subset=['category', 'channel_title', 'subscriber_count'])

# Create the sunburst figure
figure = px.sunburst(
    sunburst_data,
    path=['category', 'channel_title'],
    values='subscriber_count',
    title='Subscriber Distribution by Category and Channel'
)

figure.show()

# %%
import plotly.express as px

# Step 1: Get top 10 channels by subscriber count
top10 = df.sort_values(by='subscriber_count', ascending=False).head(10)

# Step 2: Create sunburst chart
figure = px.sunburst(
    top10,
    path=['category', 'channel_title'],
    values='subscriber_count',
    title='Top 10 Channels by Subscriber Count (Sunburst View)'
)

figure.show()

# %% [markdown]
# # outlier Handling

# %%
num=df.select_dtypes(include='number').columns
for i in num:
    sns.boxplot(data=df,x=i)
    plt.show()

# %%
column=['subscriber_count','view_count','video_count']
for i in column:
    Q1=df[i].quantile(0.25)
    Q3=df[i].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = round(Q1 - 1.5 * IQR)
    upper_bound = round(Q3 + 1.5 * IQR)
    print('lower_bound of',i,lower_bound)
    print('upper_bound',i,upper_bound)
    df[i] = np.where((df[i] > upper_bound),upper_bound,df[i])
# Out:
# lower_bound of subscriber_count -4340625
# upper_bound subscriber_count 7528375
# lower_bound of view_count -2169834607
# upper_bound view_count 3716602270
# lower_bound of video_count -2165
# upper_bound video_count 4266

# %%
df['subscriber_count'].min()
# Out:
# 0

# %%
df.head()
# Out:
#                  channel_id       channel_title          category  \
# 0  UChbmOgxUOdT-TttaPw8-DgA  Дембельский альбом  Film & Animation
# 1  UC9WxX09vr-01lDKa322FINw  Aina Asif Official  Film & Animation
# 2  UC9nuJbEL-AMJLLqc2-ej8xQ               Bongo  Film & Animation
# 3  UC5RLcUMn6TqvRJnhBTtzWUg           Sarotsi X  Film & Animation
# 4  UCidQtV5C7o1pzZ3Xo6V9fQA             楽しいショート  Film & Animation
#
#    subscriber_count  view_count  video_count                   created_at  \
# 0            162000   234156675          657  2023-10-09T13:56:49.563976Z
# 1            404000   124226694          519  2023-10-07T05:40:45.019003Z
# 2           7528375  1269940793         1361         2014-08-25T13:02:03Z
# 3           1040000  1773940347         1307  2021-01-02T21:24:52.777556Z
# 4            545000  2518747702         1048  2021-03-22T12:55:09.571244Z
#
#                                  channel_description
# 0                                                NaN
# 1  Aalamualaikum everyone\nI am Aina Asif I Hope ...
# 2  About Bongo : \nBongo owned and managed by BON...
# 3  ⚡️Sarotsi X⚡️\nAnime AMV - Anime Edit - Short ...
# 4                                                NaN

# %% [markdown]
# # Feature Engneering

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1530 entries, 0 to 1529
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   channel_id           1530 non-null   object
#  1   channel_title        1530 non-null   object
#  2   category             1530 non-null   object
#  3   subscriber_count     1530 non-null   int64
#  4   view_count           1530 non-null   int64
#  5   video_count          1530 non-null   int64
#  6   created_at           1530 non-null   object
#  7   channel_description  1452 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 95.8+ KB

# %%
df['created_at']=pd.to_datetime(df['created_at'],format='mixed')
df['day_of_the_week']=df['created_at'].dt.weekday
df['year']=df['created_at'].dt.year
df['month']=df['created_at'].dt.month

# %%
from datetime import datetime
present_date=pd.to_datetime('2025-05-05')
df['no_of_years'] = round((present_date - df['created_at']).dt.days / 365,1)

# %%
sns.boxplot(data=df,x='year')
# Out:
# <Axes: xlabel='year'>

# %%
df=df[(df['video_count']!=0)]

# %%
df['avg_views_per_video']=round(df['view_count']/df['video_count'])

# %%
df['avg_views_per_video'].max()
# Out:
# 57178496.0

# %%
df.head()
# Out:
#                  channel_id       channel_title          category  \
# 0  UChbmOgxUOdT-TttaPw8-DgA  Дембельский альбом  Film & Animation
# 1  UC9WxX09vr-01lDKa322FINw  Aina Asif Official  Film & Animation
# 2  UC9nuJbEL-AMJLLqc2-ej8xQ               Bongo  Film & Animation
# 3  UC5RLcUMn6TqvRJnhBTtzWUg           Sarotsi X  Film & Animation
# 4  UCidQtV5C7o1pzZ3Xo6V9fQA             楽しいショート  Film & Animation
#
#    subscriber_count  view_count  video_count                       created_at  \
# 0            162000   234156675          657 2023-10-09 13:56:49.563976+00:00
# 1            404000   124226694          519 2023-10-07 05:40:45.019003+00:00
# 2           7528375  1269940793         1361        2014-08-25 13:02:03+00:00
# 3           1040000  1773940347         1307 2021-01-02 21:24:52.777556+00:00
# 4            545000  2518747702         1048 2021-03-22 12:55:09.571244+00:00
#
#                                  channel_description  day_of_the_week  year  \
# 0                                                NaN                0  2023
# 1  Aalamualaikum everyone\nI am Aina Asif I Hope ...                5  2023
# 2  About Bongo : \nBongo owned and managed by BON...                0  2014
# 3  ⚡️Sarotsi X⚡️\nAnime AMV - Anime Edit - Short ...                5  2021
# 4                                                NaN                0  2021
#
#    month  avg_views_per_video
# 0     10            356403.00
# 1     10            239358.00
# 2      8            933094.00
# 3      1           1357261.00
# 4      3           2403385.00

# %%
df.describe()
# Out:
#        subscriber_count    view_count  video_count  day_of_the_week    year  \
# count           1527.00       1527.00      1527.00          1527.00 1527.00
# mean         2056415.59  996665451.47      1335.61             2.88 2016.28
# std          2613844.55 1306681816.71      1441.97             1.96    5.18
# min                0.00          4.00         1.00             0.00 2005.00
# 25%           113000.00   38699048.00       248.50             1.00 2013.00
# 50%           758000.00  306787324.00       747.00             3.00 2017.00
# 75%          3080000.00 1512726897.00      1879.50             5.00 2020.00
# max          7528375.00 3716602270.00      4266.00             6.00 2025.00
#
#         month  avg_views_per_video
# count 1527.00              1527.00
# mean     6.37           1198246.05
# std      3.31           3172983.64
# min      1.00                 4.00
# 25%      4.00             65049.00
# 50%      6.00            379119.00
# 75%      9.00           1012686.50
# max     12.00          57178496.00

# %%
df.columns
# Out:
# Index(['channel_id', 'channel_title', 'category', 'subscriber_count',
#        'view_count', 'video_count', 'created_at', 'channel_description',
#        'day_of_the_week', 'year', 'month', 'avg_views_per_video'],
#       dtype='object')

# %% [markdown]
# # splitting X and Y

# %%
x=df[['view_count', 'video_count', 'day_of_the_week', 'year', 'month',
       'avg_views_per_video']]
y=df['subscriber_count']

# %%
x=df[['view_count', 'video_count', 'day_of_the_week', 'year', 'month', 'no_of_years',
       'avg_views_per_video']]
y=df['subscriber_count']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[203], line 1
# ----> 1 x=df[['view_count', 'video_count', 'day_of_the_week', 'year', 'month', 'no_of_years',
#       2        'avg_views_per_video']]
#       3 y=df['subscriber_count']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['no_of_years'] not in index"

# %%
x_num_cols=x.select_dtypes(include='number')
x_cat_cols=x.select_dtypes(exclude='number')

# %% [markdown]
# # Train Test split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=90,test_size=0.2)

# %% [markdown]
# # Standardisation

# %%
#standard_scalar
from sklearn.preprocessing import StandardScaler
s=StandardScaler()
x_train=s.fit_transform(x_train)
x_test=s.transform(x_test)

# %%
import pickle
with open("scaler11.pkl", "wb") as f:
    pickle.dump(s, f)

# %% [markdown]
# # importing neccessary Packages and libraries

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-3.0.0-py3-none-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in c:\users\vyshn\anaconda3\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\vyshn\anaconda3\lib\site-packages (from xgboost) (1.13.1)
# Downloading xgboost-3.0.0-py3-none-win_amd64.whl (150.0 MB)
#    ---------------------------------------- 0.0/150.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/150.0 MB 320.0 kB/s eta 0:07:49
#    ---------------------------------------- 0.1/150.0 MB 1.3 MB/s eta 0:01:56
#    ---------------------------------------- 0.5/150.0 MB 3.3 MB/s eta 0:00:46
#    ---------------------------------------- 1.1/150.0 MB 6.2 MB/s eta 0:00:25
#     --------------------------------------- 2.6/150.0 MB 11.8 MB/s eta 0:00:13
#     --------------------------------------- 3.4/150.0 MB 12.8 MB/s eta 0:00:12
#    - -------------------------------------- 5.0/150.0 MB 16.0 MB/s eta 0:00:10
#    - -------------------------------------- 6.2/150.0 MB 16.5 MB/s eta 0:00:09
#    - -------------------------------------- 7.4/150.0 MB 17.5 MB/s eta 0:00:09
#    -- ------------------------------------- 7.6/150.0 MB 16.7 MB/s eta 0:00:09
#    -- ------------------------------------- 8.0/150.0 MB 16.0 MB/s eta 0:00:09
#    -- ------------------------------------- 8.0/150.0 MB 16.0 MB/s eta 0:00:09
#    -- ------------------------------------- 8.1/150.0 MB 13.6 MB/s eta 0:00:11
#    -- ------------------------------------- 8.9/150.0 MB 13.9 MB/s eta 0:00:11
#    -- ------------------------------------- 9.3/150.0 MB 13.5 MB/s eta 0:00:11
#    -- ------------------------------------- 9.7/150.0 MB 13.0 MB/s eta 0:00:11
#    -- ------------------------------------- 10.2/150.0 MB 12.8 MB/s eta 0:00:11
#    -- ------------------------------------- 10.9/150.0 MB 14.6 MB/s eta 0:00:10
#    -- ------------------------------------- 11.2/150.0 MB 14.2 MB/s eta 0:00:10
#    --- ------------------------------------ 11.4/150.0 MB 13.9 MB/s eta 0:00:10
#    --- ------------------------------------ 11.5/150.0 MB 13.4 MB/s eta 0:00:11
#    --- ------------------------------------ 11.8/150.0 MB 12.4 MB/s eta 0:00:12
#    --- ------------------------------------ 13.2/150.0 MB 12.1 MB/s eta 0:00:12
#    --- ------------------------------------ 14.2/150.0 MB 12.4 MB/s eta 0:00:11
#    ---- ----------------------------------- 15.3/150.0 MB 12.1 MB/s eta 0:00:12
#    ---- ----------------------------------- 16.5/150.0 MB 12.1 MB/s eta 0:00:12
#    ---- ----------------------------------- 17.7/150.0 MB 12.1 MB/s eta 0:00:11
#    ---- ----------------------------------- 18.7/150.0 MB 15.2 MB/s eta 0:00:09
#    ----- ---------------------------------- 19.8/150.0 MB 16.0 MB/s eta 0:00:09
#    ----- ---------------------------------- 20.7/150.0 MB 16.8 MB/s eta 0:00:08
#    ----- ----------------------------------
# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression,Lasso,Ridge,LassoCV,RidgeCV,ElasticNet,ElasticNetCV
from sklearn.ensemble import AdaBoostRegressor,GradientBoostingRegressor,RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor
from sklearn.metrics import root_mean_squared_error,mean_squared_error,r2_score
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor

# %% [markdown]
# # model Initilization

# %%
linear=LinearRegression()
lasso=Lasso()
lassocv=LassoCV()
ridge=Ridge()
ridgecv=RidgeCV()
elastic=ElasticNet()
elasticcv=ElasticNetCV()
dt_model = DecisionTreeRegressor()
rf_model = RandomForestRegressor()
ada_model = AdaBoostRegressor()
gradient=GradientBoostingRegressor()
xgb=XGBRegressor()
svr=SVR()
knn=KNeighborsRegressor()

# %% [markdown]
# # Training model with polynomial Features

# %%
#polynomial Regression
poly=PolynomialFeatures()
x_train_poly=poly.fit_transform(x_train)
x_test_poly=poly.transform(x_test)

# %%
Model=[]
TrainRMSE=[]
TestRMSE=[]
TrainScore=[]
TestScore=[]
Fit=[]
model=['LinearRegression',
 'Lasso',
 'LassoCV',
 'Ridge',
 'RidgeCV',
 'ElasticNet',
 'ElasticNetCV']

# %%
for i in [linear,lasso,lassocv,ridge,ridgecv,elastic,elasticcv]:
    i.fit(x_train_poly,y_train)
    Model.append(i)
    y_train_predict=i.predict(x_train_poly)
    y_test_predict=i.predict(x_test_poly)
    print('mean_squared_error of train of ',str(i),mean_squared_error(y_train,y_train_predict))
    print('mean_squared_error of test of ',str(i),mean_squared_error(y_test,y_test_predict))
    print('root_mean_squared_error train of,',str(i),root_mean_squared_error(y_train,y_train_predict))
    TrainRMSE.append(root_mean_squared_error(y_train,y_train_predict))
    print('root_mean_squared_error test of',str(i),root_mean_squared_error(y_test,y_test_predict))
    TestRMSE.append(root_mean_squared_error(y_test,y_test_predict))
    r2_score_train=r2_score(y_train,y_train_predict)
    TrainScore.append(r2_score_train)
    r2_score_test=r2_score(y_test,y_test_predict)
    TestScore.append(r2_score_test)
    #Bias Varaince Tradeoff
    if r2_score_train<0.5 and r2_score_test<0.5:
        if abs(r2_score_train)==0 and abs(r2_score_test)==0:
            Fit.append('No Fit')
        else:
            Fit.append('Underfit')
    else:
        if abs(r2_score_train-r2_score_test)<=0.10:
            Fit.append('Good_fit')
        elif abs(r2_score_train-r2_score_test)>0.10:
            Fit.append('overfit')
        else:
            Fit.append('fit')
    print(f'train r2 score{r2_score_train},test r2 score{r2_score_test}')
    print("*"*100)
# Out:
# mean_squared_error of train of  LinearRegression() 1164494009052.4612
# mean_squared_error of test of  LinearRegression() 1569529342123.8381
# root_mean_squared_error train of, LinearRegression() 1079117.236009351
# root_mean_squared_error test of LinearRegression() 1252808.5815972998
# train r2 score0.8234609523906585,test r2 score0.7965617963411591
# ****************************************************************************************************
# mean_squared_error of train of  Lasso() 1175030241477.4458
# mean_squared_error of test of  Lasso() 1541311030514.5115
# root_mean_squared_error train of, Lasso() 1083988.1186975464
# root_mean_squared_error test of Lasso() 1241495.481471645
# train r2 score0.8218636436683827,test r2 score0.8002193785666171
# ****************************************************************************************************
# mean_squared_error of train of  LassoCV() 1177354956828.6912
# mean_squared_error of test of  LassoCV() 1542986187282.994
# root_mean_squared_error train of, LassoCV() 1085059.8862867851
# root_mean_squared_error test of LassoCV() 1242169.9510465523
# train r2 score0.8215112133159024,test r2 score0.8000022492179131
# ****************************************************************************************************
# mean_squared_error of train of  Ridge() 1175147855692.9817
# mean_squared_error of test of  Ridge() 1542796958679.909
# root_mean_squared_error train of, Ridge() 1084042.368034101
# root_mean_squared_error test of Ridge() 1242093.7801470181
# train r2 score0.8218458131759675,test r2 score0.8000267765243223
# ****************************************************************************************************
# mean_squared_error of train of  RidgeCV() 1175147855692.993
# mean_squared_error of test of  RidgeCV() 1542796958680.4666
# root_mean_squared_error train of, RidgeCV() 1084042.3680341064
# root_mean_squared_error test of RidgeCV() 1242093.7801472426
# train r2 score0.8218458131759657,test r2 score0.80002677652425
# ****************************************************************************************************
# mean_squared_error of train of  ElasticNet() 1589387735072.0342
# mean_squared_error of test of  ElasticNet() 2227875393598.3384
# root_mean_squared_error train of, ElasticNet() 1260709.2190794966
# root_mean_squared_error test of ElasticNet() 1492606.9119491368
# train r2 score0.7590464228666165,test r2 score0.7112287385235655
# ****************************************************************************************************
# mean_squared_error of train of  ElasticNetCV() 6576802396941.14
# mean_squared_error of test of  ElasticNetCV() 7742751745955.464
# root_mean_squared_error train of, ElasticNetCV() 2564527.714208045
# root_mean_squared_error test of ElasticNetCV() 2782580.0520300334
# train r2 score0.002946840048091537,test r2 score-0.0035948129788136995
# ****************************************************************************************************

# %%
df1=pd.DataFrame({
    "Model": model,
    "TrainRMSE": TrainRMSE,
    "TestRMSE": TestRMSE,
    "TrainScore": TrainScore,
    "TestScore": TestScore,
    "Fit": Fit
})
df1

# %% [markdown]
# # without Polynomial Features

# %%
linear=LinearRegression()
lasso=Lasso()
lassocv=LassoCV()
ridge=Ridge()
ridgecv=RidgeCV()
elastic=ElasticNet()
elasticcv=ElasticNetCV()
dt_model = DecisionTreeRegressor()
rf_model = RandomForestRegressor()
ada_model = AdaBoostRegressor()
gradient=GradientBoostingRegressor()
xgb=XGBRegressor()
svr=SVR()
knn=KNeighborsRegressor()

# %%
Model=[]
TrainRMSE=[]
TestRMSE=[]
TrainScore=[]
TestScore=[]
Fit=[]

# %%
for i in [linear,lasso,lassocv,ridge,ridgecv,elastic,elasticcv,dt_model,rf_model,ada_model,gradient,xgb,svr,knn]:
    i.fit(x_train,y_train)
    Model.append(i)
    y_train_predict=i.predict(x_train)
    y_test_predict=i.predict(x_test)
    print('mean_squared_error of train of ',str(i),mean_squared_error(y_train,y_train_predict))
    print('mean_squared_error of test of ',str(i),mean_squared_error(y_test,y_test_predict))
    print('root_mean_squared_error train of,',str(i),root_mean_squared_error(y_train,y_train_predict))
    TrainRMSE.append(root_mean_squared_error(y_train,y_train_predict))
    print('root_mean_squared_error test of',str(i),root_mean_squared_error(y_test,y_test_predict))
    TestRMSE.append(root_mean_squared_error(y_test,y_test_predict))
    r2_score_train=r2_score(y_train,y_train_predict)
    TrainScore.append(r2_score_train)
    r2_score_test=r2_score(y_test,y_test_predict)
    TestScore.append(r2_score_test)
    #Bias Varaince Tradeoff
    if r2_score_train<0.5 and r2_score_test<0.5:
        if abs(r2_score_train)==0 and abs(r2_score_test)==0:
            Fit.append('No Fit')
        else:
            Fit.append('Underfit')
    else:
        if abs(r2_score_train-r2_score_test)<=0.10:
            Fit.append('Good_fit')
        elif abs(r2_score_train-r2_score_test)>0.10:
            Fit.append('overfit')
        else:
            Fit.append('fit')
    print(f'train r2 score{r2_score_train},test r2 score{r2_score_test}')
    print("*"*100)
# Out:
# mean_squared_error of train of  LinearRegression() 1267775808782.8318
# mean_squared_error of test of  LinearRegression() 1646768055991.5952
# root_mean_squared_error train of, LinearRegression() 1125955.509237746
# root_mean_squared_error test of LinearRegression() 1283264.6087193377
# train r2 score0.8078032758220908,test r2 score0.7865503204289516
# ****************************************************************************************************
# mean_squared_error of train of  Lasso() 1268202652495.2285
# mean_squared_error of test of  Lasso() 1650446565043.3958
# root_mean_squared_error train of, Lasso() 1126145.0406121002
# root_mean_squared_error test of Lasso() 1284697.071314244
# train r2 score0.8077385656716917,test r2 score0.7860735219049887
# ****************************************************************************************************
# mean_squared_error of train of  LassoCV() 1286541119445.7366
# mean_squared_error of test of  LassoCV() 1692685526816.0598
# root_mean_squared_error train of, LassoCV() 1134257.9598335365
# root_mean_squared_error test of LassoCV() 1301032.4849195965
# train r2 score0.8049584264310506,test r2 score0.7805986204317754
# ****************************************************************************************************
# mean_squared_error of train of  Ridge() 1268259499652.6052
# mean_squared_error of test of  Ridge() 1651228978034.2983
# root_mean_squared_error train of, Ridge() 1126170.2800432113
# root_mean_squared_error test of Ridge() 1285001.5478723357
# train r2 score0.8077299475569186,test r2 score0.785972107621664
# ****************************************************************************************************
# mean_squared_error of train of  RidgeCV() 1268259499652.602
# mean_squared_error of test of  RidgeCV() 1651228978033.5261
# root_mean_squared_error train of, RidgeCV() 1126170.28004321
# root_mean_squared_error test of RidgeCV() 1285001.547872035
# train r2 score0.8077299475569191,test r2 score0.7859721076217641
# ****************************************************************************************************
# mean_squared_error of train of  ElasticNet() 1824165323092.0295
# mean_squared_error of test of  ElasticNet() 2436088662341.6465
# root_mean_squared_error train of, ElasticNet() 1350616.64549643
# root_mean_squared_error test of ElasticNet() 1560797.444366708
# train r2 score0.7234537865225328,test r2 score0.6842406904289973
# ****************************************************************************************************
# mean_squared_error of train of  ElasticNetCV() 6589014918810.776
# mean_squared_error of test of  ElasticNetCV() 7753129965422.039
# root_mean_squared_error train of, ElasticNetCV() 2566907.6568530425
# root_mean_squared_error test of ElasticNetCV() 2784444.2830521925
# train r2 score0.0010954033184785716,test r2 score-0.0049400100826793025
# ****************************************************************************************************
# mean_squared_error of train of  DecisionTreeRegressor() 1735015413.8513513
# mean_squared_error of test of  DecisionTreeRegressor() 3042045654438.2646
# root_mean_squared_error train of, DecisionTreeRegressor() 41653.516224339946
# root_mean_squared_error test of DecisionTreeRegressor() 1744146.1104042472
# train r2 score0.9997369690471847,test r2 score0.605698162641757
# ****************************************************************************************************
# mean_squared_error of train of  RandomForestRegressor() 182260175910.80984
# mean_squared_error of test of  RandomForestRegressor() 1677524109123.5906
# root_mean_squared_error train of, RandomForestRegressor() 426919.4021250497
# root_mean_squared_error test of RandomForestRegressor() 1295192.6918893538
# train r2 score0.9723690825180056,test r2 score0.782563802921517
# ****************************************************************************************************
# mean_squared_error of train of  AdaBoostRegressor() 1195954165929.0945
# mean_squared_error of test of  AdaBoostRegressor() 1972968260295.0408
# root_mean_squared_error train of, AdaBoostRegressor() 1093596.8937085979
# root_mean_squared_error test of AdaBoostRegressor() 1404623.8857057218
# train r2 score0.8186915451721873,test r2 score0.7442691206988201
# ****************************************************************************************************
# mean_squared_error of train of  GradientBoostingRegressor() 632718722756.7091
# mean_squared_error of test of  GradientBoostingRegressor() 1656261379267.8535
# root_mean_squared_error train of, GradientBoostingRegressor() 795436.1839624277
# root_mean_squared_error test of GradientBoostingRegressor() 1286958.1886245774
# train r2 score0.904078887609772,test r2 score0.7853198212071522
# ****************************************************************************************************
# mean_squared_error of train of  XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...) 11553630725.40462
# mean_squared_error of test of  XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...) 1916136926846.9429
# root_mean_squared_error train of, XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...) 107487.8166370711
# root_mean_squared_error test of XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...) 1384245.9777246756
# train r2 score0.9982484521613361,test r2 score0.7516354464360457
# ****************************************************************************************************
# mean_squared_error of train of  SVR() 8162538503524.193
# mean_squared_error of test of  SVR() 9860036037827.574
# root_mean_squared_error train of, SVR() 2857015.6638569892
# root_mean_squared_error test of SVR() 3140069.4320074474
# train r2 score-0.2374531447003967,test r2 score-0.2780315510589595
# ****************************************************************************************************
# mean_squared_error of train of  KNeighborsRegressor() 1100857454376.4373
# mean_squared_error of test of  KNeighborsRegressor() 1955270465283.889
# root_mean_squared_error train of, KNeighborsRegressor() 1049217.5438756433
# root_mean_squared_error test of KNeighborsRegressor() 1398309.8602541173
# train r2 score0.833108350031447,test r2 score0.7465630616460592
# ****************************************************************************************************

# %%
model=['LinearRegression',
 'Lasso',
 'LassoCV',
 'Ridge',
 'RidgeCV',
 'ElasticNet',
 'ElasticNetCV',
 'DecisionTreeRegressor',
 'RandomForestRegressor',
 'AdaBoostRegressor',
 'GradientBoostingRegressor',
 'XGBRegressor',
 'SVR',
 'knn']

# %%
new_data = pd.DataFrame({
    "Model": model,
    "TrainRMSE": TrainRMSE,
    "TestRMSE": TestRMSE,
    "TrainScore": TrainScore,
    "TestScore": TestScore,  
    "Fit": Fit
})
new_data
# Out:
#                         Model     TrainRMSE      TestRMSE  TrainScore  \
# 0            LinearRegression  1.125956e+06  1.283265e+06    0.807803
# 1                       Lasso  1.126145e+06  1.284697e+06    0.807739
# 2                     LassoCV  1.134258e+06  1.301032e+06    0.804958
# 3                       Ridge  1.126170e+06  1.285002e+06    0.807730
# 4                     RidgeCV  1.126170e+06  1.285002e+06    0.807730
# 5                  ElasticNet  1.350617e+06  1.560797e+06    0.723454
# 6                ElasticNetCV  2.566908e+06  2.784444e+06    0.001095
# 7       DecisionTreeRegressor  4.165352e+04  1.744146e+06    0.999737
# 8       RandomForestRegressor  4.269194e+05  1.295193e+06    0.972369
# 9           AdaBoostRegressor  1.093597e+06  1.404624e+06    0.818692
# 10  GradientBoostingRegressor  7.954362e+05  1.286958e+06    0.904079
# 11               XGBRegressor  1.074878e+05  1.384246e+06    0.998248
# 12                        SVR  2.857016e+06  3.140069e+06   -0.237453
# 13                        knn  1.049218e+06  1.398310e+06    0.833108
#
#     TestScore       Fit
# 0    0.786550  Good_fit
# 1    0.786074  Good_fit
# 2    0.780599  Good_fit
# 3    0.785972  Good_fit
# 4    0.785972  Good_fit
# 5    0.684241  Good_fit
# 6   -0.004940  Underfit
# 7    0.605698   overfit
# 8    0.782564   overfit
# 9    0.744269  Good_fit
# 10   0.785320   overfit
# 11   0.751635   overfit
# 12  -0.278032  Underfit
# 13   0.746563  Good_fit

# %% [markdown]
# # Hyper Parameter Tuning for Ada Boost Regressor

# %%
from sklearn.model_selection import GridSearchCV

base_estimator = DecisionTreeRegressor(max_depth=3)

param_grid = {
    "n_estimators": [50, 100, 200],
    "learning_rate": [0.01, 0.1, 1.0],
    "loss": ["linear", "square", "exponential"]
}

ada_model = AdaBoostRegressor()

grid_search = GridSearchCV(ada_model, param_grid, cv=5, scoring='neg_root_mean_squared_error', n_jobs=-1)
grid_search.fit(x_train, y_train)

print("Best Hyperparameters:", grid_search.best_params_)
# Out:
# Best Hyperparameters: {'learning_rate': 0.01, 'loss': 'exponential', 'n_estimators': 50}

# %%
ada_boost=AdaBoostRegressor(
    n_estimators=50,
    learning_rate=0.01,
    loss='exponential')

# %%
ada_boost.fit(x_train,y_train)
# Out:
# AdaBoostRegressor(learning_rate=0.01, loss='exponential')

# %%
y_train_predict=ada_boost.predict(x_train)
y_test_predict=ada_boost.predict(x_test)
mean_squared_error(y_train,y_train_predict)
mean_squared_error(y_test,y_test_predict)
print(root_mean_squared_error(y_train,y_train_predict))
print(root_mean_squared_error(y_test,y_test_predict))

r2_score_train=r2_score(y_train,y_train_predict)
r2_score_test=r2_score(y_test,y_test_predict)
print(r2_score_train,r2_score_test)
# Out:
# 1048380.4929587498
# 1346452.5468253416
# 0.8333745314070332 0.7650122745918496

# %%
from sklearn.model_selection import RandomizedSearchCV

param_dist = {
    "n_estimators": [50, 100, 200, 300],
    "learning_rate": [0.001, 0.01, 0.1, 1.0],
    "loss": ["linear", "square", "exponential"]
}

random_search = RandomizedSearchCV(AdaBoostRegressor(), param_dist, cv=5, n_iter=10, scoring='neg_root_mean_squared_error', n_jobs=-1)
random_search.fit(x_train, y_train)

print("Best Hyperparameters:", random_search.best_params_)
# Out:
# Best Hyperparameters: {'n_estimators': 100, 'loss': 'linear', 'learning_rate': 0.001}

# %%
ada_boost_r=AdaBoostRegressor(
    n_estimators=100,
    learning_rate=0.01,
    loss='linear'
)

# %%
ada_boost_r.fit(x_train,y_train)
y_train_predict=ada_boost_r.predict(x_train)
y_test_predict=ada_boost_r.predict(x_test)
mean_squared_error(y_train,y_train_predict)
mean_squared_error(y_test,y_test_predict)
print(root_mean_squared_error(y_train,y_train_predict))
print(root_mean_squared_error(y_test,y_test_predict))
r2_score_train=r2_score(y_train,y_train_predict)
r2_score_test=r2_score(y_test,y_test_predict)
print(r2_score_train,r2_score_test)
# Out:
# 1041835.3607389741
# 1349107.1377764654
# 0.8354485520871604 0.7640847837389411

# %% [markdown]
# # saving the file

# %%
with open("ada.pkl", "wb") as file:
    pickle.dump(ada_model, file)
